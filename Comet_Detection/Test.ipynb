# %%
# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img = mpimg.imread('WhatsApp Image 2022-07-18 at 11.01.28 AM.JPEG')
plt.show()
imgplot = plt.imshow(img)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import cv2
import tensorflow as tf

CATEGORIES = ["Not_Comet", "Comet"]


def prepare(filepath):
    size=300 # 50 in txt-based
    img_array = cv2.imread(filepath, cv2.IMREAD_GRAYSCALE)
    new_array = cv2.resize(img_array, (size, size))
    return new_array.reshape(-1, size, size, 1)


model = tf.keras.models.load_model("64x3-CNN.model")

prediction = model.predict([prepare('WhatsApp Image 2022-07-18 at 11.01.28 AM.JPEG')])
print(prediction)  # will be a list in a list.
print(CATEGORIES[int(prediction[0][0])])
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# <ipython-input-2-e2ff6da90e19> in <module>
#      12
#      13
# ---> 14 model = tf.keras.models.load_model("64x3-CNN.model")
#      15
#      16 prediction = model.predict([prepare('WhatsApp Image 2022-07-18 at 11.01.28 AM.JPEG')])
#
# ~\anaconda3\envs\tf_2.9.0\lib\site-packages\tensorflow\python\keras\saving\save.py in load_model(filepath, custom_objects, compile, options)
#     204         filepath = path_to_string(filepath)
#     205         if isinstance(filepath, str):
# --> 206           return saved_model_load.load(filepath, compile, options)
#     207
#     208   raise IOError(
#
# ~\anaconda3\envs\tf_2.9.0\lib\site-packages\tensorflow\python\keras\saving\saved_model\load.py in load(path, compile, options)
#     150   for node_id, loaded_node in keras_loader.loaded_nodes.items():
#     151     nodes_to_load[keras_loader.get_path(node_id)] = loaded_node
# --> 152   loaded = tf_load.load_partial(path, nodes_to_load, options=options)
#     153
#     154   # Finalize the loaded layers and remove the extra tracked dependencies.
#
# ~\anaconda3\envs\tf_2.9.0\lib\site-packages\tensorflow\python\saved_model\load.py in load_partial(export_dir, filters, tags, options)
#     773     A dictionary mapping node paths from the filter to loaded objects.
#     774   """
# --> 775   return load_internal(export_dir, tags, options, filters=filters)
#     776
#     777
#
# ~\anaconda3\envs\tf_2.9.0\lib\site-packages\tensorflow\python\saved_model\load.py in load_internal(export_dir, tags, options, loader_cls, filters)
#     904       try:
#     905         loader = loader_cls(object_graph_proto, saved_model_proto, export_dir,
# --> 906                             ckpt_options, filters)
#     907       except errors.NotFoundError as err:
#     908         raise FileNotFoundError(
#
# ~\anaconda3\envs\tf_2.9.0\lib\site-packages\tensorflow\python\saved_model\load.py in __init__(self, object_graph_proto, saved_model_proto, export_dir, ckpt_options, filters)
#     161
#     162     self._load_all()
# --> 163     self._restore_checkpoint()
#     164
#     165     for node in self._nodes:
#
# ~\anaconda3\envs\tf_2.9.0\lib\site-packages\tensorflow\python\saved_model\load.py in _restore_checkpoint(self)
#     487                                   self._checkpoint_options).expect_partial()
#     488     else:
# --> 489       load_status = saver.restore(variables_path, self._checkpoint_options)
#     490     load_status.assert_existing_objects_matched()
#     491     checkpoint = load_status._checkpoint
#
# ~\anaconda3\envs\tf_2.9.0\lib\site-packages\tensorflow\python\training\tracking\util.py in restore(self, save_path, options)
#    1337         options=options)
#    1338     base.CheckpointPosition(
# -> 1339         checkpoint=checkpoint, proto_id=0).restore(self._graph_view.root)
#    1340
#    1341     # Attached dependencies are not attached to the root, so should be restored
#
# ~\anaconda3\envs\tf_2.9.0\lib\site-packages\tensorflow\python\training\tracking\base.py in restore(self, trackable)
#     256         # This object's correspondence with a checkpointed object is new, so
#     257         # process deferred restorations for it and its dependencies.
# --> 258         restore_ops = trackable._restore_from_checkpoint_position(self)  # pylint: disable=protected-access
#     259         if restore_ops:
#     260           self._checkpoint.new_restore_ops(restore_ops)
#
# ~\anaconda3\envs\tf_2.9.0\lib\site-packages\tensorflow\python\training\tracking\base.py in _restore_from_checkpoint_position(self, checkpoint_position)
#     970           ._single_restoration_from_checkpoint_position(
#     971               checkpoint_position=current_position,
# --> 972               visit_queue=visit_queue))
#     973       restore_ops.extend(new_restore_ops)
#     974       tensor_saveables.update(new_tensor_saveables)
#
# ~\anaconda3\envs\tf_2.9.0\lib\site-packages\tensorflow\python\training\tracking\base.py in _single_restoration_from_checkpoint_position(self, checkpoint_position, visit_queue)
#    1005                                                []).append(child_position)
#    1006       else:
# -> 1007         if child_position.bind_object(trackable=local_object):
#    1008           # This object's correspondence is new, so dependencies need to be
#    1009           # visited. Delay doing it so that we get a breadth-first dependency
#
# ~\anaconda3\envs\tf_2.9.0\lib\site-packages\tensorflow\python\training\tracking\base.py in bind_object(self, trackable)
#     310                   proto_id=slot_restoration.slot_variable_id),
#     311               variable=trackable,
# --> 312               slot_name=slot_restoration.slot_name)
#     313       return True  # New assignment
#     314     else:
#
# ~\anaconda3\envs\tf_2.9.0\lib\site-packages\tensorflow\python\keras\optimizer_v2\optimizer_v2.py in _create_or_restore_slot_variable(self, slot_variable_position, slot_name, variable)
#    1395       # If we've either made this slot variable, or if we've pulled out an
#    1396       # existing slot variable, we should restore it.
# -> 1397       slot_variable_position.restore(slot_variable)
#    1398     else:
#    1399       # We didn't make the slot variable. Defer restoring until it gets created
#
# ~\anaconda3\envs\tf_2.9.0\lib\site-packages\tensorflow\python\training\tracking\base.py in restore(self, trackable)
#     256         # This object's correspondence with a checkpointed object is new, so
#     257         # process deferred restorations for it and its dependencies.
# --> 258         restore_ops = trackable._restore_from_checkpoint_position(self)  # pylint: disable=protected-access
#     259         if restore_ops:
#     260           self._checkpoint.new_restore_ops(restore_ops)
#
# ~\anaconda3\envs\tf_2.9.0\lib\site-packages\tensorflow\python\training\tracking\base.py in _restore_from_checkpoint_position(self, checkpoint_position)
#     976     restore_ops.extend(
#     977         current_position.checkpoint.restore_saveables(
# --> 978             tensor_saveables, python_saveables))
#     979     return restore_ops
#     980
#
# ~\anaconda3\envs\tf_2.9.0\lib\site-packages\tensorflow\python\training\tracking\util.py in restore_saveables(self, tensor_saveables, python_saveables)
#     307              "expecting %s") % (tensor_saveables.keys(), validated_names))
#     308       new_restore_ops = functional_saver.MultiDeviceSaver(
# --> 309           validated_saveables).restore(self.save_path_tensor, self.options)
#     310       if not context.executing_eagerly():
#     311         for name, restore_op in sorted(new_restore_ops.items()):
#
# ~\anaconda3\envs\tf_2.9.0\lib\site-packages\tensorflow\python\training\saving\functional_saver.py in restore(self, file_prefix, options)
#     337       restore_ops = tf_function_restore()
#     338     else:
# --> 339       restore_ops = restore_fn()
#     340
#     341     for callback in self._after_restore_callbacks:
#
# ~\anaconda3\envs\tf_2.9.0\lib\site-packages\tensorflow\python\training\saving\functional_saver.py in restore_fn()
#     321       for device, saver in sorted(self._single_device_savers.items()):
#     322         with ops.device(device):
# --> 323           restore_ops.update(saver.restore(file_prefix, options))
#     324
#     325       return restore_ops
#
# ~\anaconda3\envs\tf_2.9.0\lib\site-packages\tensorflow\python\training\saving\functional_saver.py in restore(self, file_prefix, options)
#     114                                           structured_restored_tensors):
#     115       restore_ops[saveable.name] = saveable.restore(
# --> 116           restored_tensors, restored_shapes=None)
#     117     return restore_ops
#     118
#
# ~\anaconda3\envs\tf_2.9.0\lib\site-packages\tensorflow\python\training\saving\saveable_object_util.py in restore(self, restored_tensors, restored_shapes)
#     128     # Copy the restored tensor to the variable's device.
#     129     with ops.device(self._var_device):
# --> 130       restored_tensor = array_ops.identity(restored_tensor)
#     131       return resource_variable_ops.shape_safe_assign_variable_handle(
#     132           self.handle_op, self._var_shape, restored_tensor)
#
# ~\anaconda3\envs\tf_2.9.0\lib\site-packages\tensorflow\python\util\dispatch.py in wrapper(*args, **kwargs)
#     204     """Call target, and fall back on dispatchers if there is a TypeError."""
#     205     try:
# --> 206       return target(*args, **kwargs)
#     207     except (TypeError, ValueError):
#     208       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# ~\anaconda3\envs\tf_2.9.0\lib\site-packages\tensorflow\python\ops\array_ops.py in identity(input, name)
#     286     # variables. Variables have correct handle data when graph building.
#     287     input = ops.convert_to_tensor(input)
# --> 288   ret = gen_array_ops.identity(input, name=name)
#     289   # Propagate handle data for happier shape inference for resource variables.
#     290   if hasattr(input, "_handle_data"):
#
# ~\anaconda3\envs\tf_2.9.0\lib\site-packages\tensorflow\python\ops\gen_array_ops.py in identity(input, name)
#    3950       return _result
#    3951     except _core._NotOkStatusException as e:
# -> 3952       _ops.raise_from_not_ok_status(e, name)
#    3953     except _core._FallbackException:
#    3954       pass
#
# ~\anaconda3\envs\tf_2.9.0\lib\site-packages\tensorflow\python\framework\ops.py in raise_from_not_ok_status(e, name)
#    6895   message = e.message + (" name: " + name if name is not None else "")
#    6896   # pylint: disable=protected-access
# -> 6897   six.raise_from(core._status_to_exception(e.code, message), None)
#    6898   # pylint: enable=protected-access
#    6899
#
# ~\anaconda3\envs\tf_2.9.0\lib\site-packages\six.py in raise_from(value, from_value)
#
# InternalError: Failed copying input tensor from /job:localhost/replica:0/task:0/device:CPU:0 to /job:localhost/replica:0/task:0/device:GPU:0 in order to run Identity: Dst tensor is not initialized. [Op:Identity]
